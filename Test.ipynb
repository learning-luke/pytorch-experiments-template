# %% [markdown]
# # Test Notebook
#
# Test functions for `iss4`.

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import torch

from utils.data_loaders import load_dataset

SEED = 1

def imshow(img, ax, title=None):

    img = img.numpy().transpose((1,2,0))

    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])

    img = std * img + mean

    img = np.clip(img, 0, 1)
    ax.imshow(img)
    
def seedme():
    random.seed(SEED)
    np.random.seed(SEED)
    torch.manual_seed(SEED)

seedme()

# %% [markdown]
# ### Implementing a constrastive learning dataloader
#
# Step 1: get regular dataloaders

# %%
batch_size = 1
workers = 0

train_loader, test_loader, im_size = load_dataset('cifar10', '../datasets/cifar', batch_size, workers)

# %% [markdown]
# Step 2: write a get views function which will convert a data sample into a pair of views

# %%
for i, (input, target) in enumerate(train_loader): 
    if i > 3:
        break
    fig, ax = plt.subplots(1,2)
    
    imshow(input[0].squeeze(), ax[0])
    imshow(input[1].squeeze(), ax[1])
